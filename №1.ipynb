# %% [markdown]
# <a href="https://colab.research.google.com/github/5-Olga-666/1-semestr/blob/5-Olga-666-patch-1/%E2%84%961.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x = [0,1,2,3,4]
y = [0,2,4,6,8]
plt.figure(figsize=(8,5), dpi=100)
plt.plot(x,y,'b^--')
